# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %%
plt.style.use("ggplot")
rcParams['figure.figsize'] = (15,10)

# %%
df = pd.read_csv("C:\\Users\\ammar\\OneDrive - University of Stirling\\Documents\\University of Stirling\\MSc Big Data\\Dissertation\\Condor Results\\QuitAll results\\QAresults.csv")

# %%
df
# Out:
#      deathrate  maxABdose  time 1  dose 1  time 2  dose 2  time 3  dose 3  \
# 0        0.087     0.8946       2  0.5066    8.78  0.2150   12.13  0.1730
# 1        0.095     0.8982       2  0.5798   11.42  0.2223   16.62  0.0961
# 2        0.087     0.8993       2  0.5061    9.22  0.2464   14.29  0.1468
# 3        0.086     0.8934       2  0.4954   12.30  0.1978   15.31  0.2002
# 4        0.087     0.8965       2  0.5241    7.91  0.1921   15.77  0.1803
# ..         ...        ...     ...     ...     ...     ...     ...     ...
# 795      0.414     0.8945       2  0.7734   11.77  0.1199   18.34  0.0012
# 796      0.409     0.8970       2  0.7952   11.83  0.0935   19.75  0.0083
# 797      0.413     0.8997       2  0.7814   10.39  0.1182   21.62  0.0001
# 798      0.410     0.8928       2  0.7953    9.86  0.0958   15.63  0.0017
# 799      0.408     0.8998       2  0.7781   12.80  0.1217   22.01  0.0000
#
#      processing time  samples  quitAll
# 0            5279.67     1000     0.01
# 1            5175.24     1000     0.01
# 2            5204.10     1000     0.01
# 3            5273.50     1000     0.01
# 4            5250.38     1000     0.01
# ..               ...      ...      ...
# 795          5717.27     1000     0.30
# 796          5575.70     1000     0.30
# 797          5588.50     1000     0.30
# 798          5602.16     1000     0.30
# 799          5650.17     1000     0.30
#
# [800 rows x 11 columns]

# %%
# Group means
means = df.groupby("quitAll").mean().reset_index("quitAll")
display(means)
# Out:
#     quitAll  deathrate    dose 1   time 2    dose 2   time 3    dose 3  \
# 0      0.01    0.08708  0.506870   9.1984  0.228106  14.8314  0.160528
# 1      0.02    0.10264  0.509754   9.2512  0.240204  15.0182  0.144968
# 2      0.03    0.11782  0.532324  10.0400  0.253250  15.7464  0.109150
# 3      0.04    0.13200  0.552266  10.3554  0.260856  15.8312  0.081886
# 4      0.05    0.14548  0.560244  10.1930  0.258888  16.1054  0.076036
# 5      0.06    0.15996  0.589244  10.3200  0.257148  16.0348  0.047998
# 6      0.07    0.17244  0.601068  11.1018  0.261364  17.7664  0.033558
# 7      0.08    0.18376  0.606896  10.6380  0.263046  17.4422  0.026422
# 8      0.09    0.19624  0.622648  11.2960  0.254602  17.1976  0.019182
# 9      0.10    0.20684  0.644574  11.5860  0.241562  18.4230  0.009994
# 10     0.11    0.21806  0.639710  11.3816  0.242684  18.8356  0.013696
# 11     0.12    0.23052  0.647936  11.7698  0.235198  18.6996  0.012332
# 12     0.15    0.26250  0.677532  11.5654  0.208946  18.7540  0.009074
# 13     0.20    0.31616  0.707526  11.6250  0.180840  19.7750  0.006462
# 14     0.25    0.36392  0.731902  11.8878  0.160146  18.7900  0.003696
# 15     0.30    0.41062  0.776022  12.0300  0.116594  21.1440  0.002338
#
#     processing time
# 0         5248.4426
# 1         5723.1918
# 2         5299.1804
# 3         5363.3600
# 4         5658.3248
# 5         5364.0004
# 6         5445.5082
# 7         5651.0460
# 8         5418.0242
# 9         5471.3410
# 10        5174.8488
# 11        3857.4924
# 12        5528.5122
# 13        5622.3780
# 14        6055.2344
# 15        5622.0274

# %%
# Group Stds (equal variances ?)
stds = df.groupby("quitAll").std(ddof=1).reset_index()
display(stds)
# Out:
#     quitAll  deathrate  maxABdose  time 1    dose 1    time 2    dose 2  \
# 0      0.01   0.004085   0.003733     0.0  0.027211  1.225803  0.034129
# 1      0.02   0.004839   0.003710     0.0  0.043195  1.334963  0.038828
# 2      0.03   0.004592   0.004308     0.0  0.035266  1.056247  0.043843
# 3      0.04   0.004781   0.004220     0.0  0.040460  1.480024  0.036644
# 4      0.05   0.005300   0.004459     0.0  0.036252  1.071448  0.044484
# 5      0.06   0.003891   0.003844     0.0  0.032646  1.285359  0.036612
# 6      0.07   0.004875   0.002988     0.0  0.035474  1.354648  0.035232
# 7      0.08   0.004148   0.003316     0.0  0.038633  1.436617  0.041135
# 8      0.09   0.004128   0.003291     0.0  0.033162  1.374706  0.039745
# 9      0.10   0.005176   0.003560     0.0  0.032958  1.299754  0.029987
# 10     0.11   0.004679   0.003468     0.0  0.034131  1.314705  0.032049
# 11     0.12   0.004626   0.004328     0.0  0.032005  1.448416  0.031386
# 12     0.15   0.004829   0.003919     0.0  0.031004  1.486044  0.033174
# 13     0.20   0.006018   0.004389     0.0  0.027899  1.422427  0.028454
# 14     0.25   0.006986   0.003717     0.0  0.032980  1.404723  0.033934
# 15     0.30   0.004544   0.004246     0.0  0.037127  1.571004  0.035613
#
#       time 3    dose 3  processing time  samples
# 0   1.475120  0.040867        81.903511      0.0
# 1   1.692440  0.051025      1115.305104      0.0
# 2   1.909504  0.049836       206.849664      0.0
# 3   1.829469  0.049562       291.867306      0.0
# 4   2.356790  0.049689       858.054408      0.0
# 5   2.652820  0.042343        78.769651      0.0
# 6   3.806129  0.033739       228.218103      0.0
# 7   4.855389  0.031627       750.446579      0.0
# 8   3.869141  0.022662       141.414750      0.0
# 9   4.962087  0.010908        78.735498      0.0
# 10  4.952340  0.017261       894.855623      0.0
# 11  5.075241  0.016041      1159.162316      0.0
# 12  4.616763  0.012757        84.687678      0.0
# 13  5.331003  0.007551        86.966148      0.0
# 14  5.117818  0.005144      1199.015228      0.0
# 15  6.242103  0.002741       379.006435      0.0

# %%
# Plot groups
ax = sns.violinplot(x="quitAll", y="deathrate", data=df)
ax = sns.swarmplot(x="quitAll", y="deathrate", data=df,
color="white")
ax = sns.swarmplot(x="quitAll", y="deathrate", color="black", data=means, size=10)
# Out:
# C:\Users\ammar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 38.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ammar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 36.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ammar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 32.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ammar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 30.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ammar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 28.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ammar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ammar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 34.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import scipy.stats
import statsmodels.api as sm
#import statsmodels.stats.api as sms
import statsmodels.formula.api as smf
from statsmodels.stats.stattools import jarque_bera

# %%
# ANOVA
lm = smf.ols('deathrate ~ quitAll', data=df).fit()
lm

# %%
anova_table = sm.stats.anova_lm(lm, typ=2)
display(anova_table)
# Out:
#             sum_sq     df             F  PR(>F)
# quitAll   6.384365    1.0  89265.183211     0.0
# Residual  0.057074  798.0           NaN     NaN

# %%
df.drop(columns=['maxABdose', 'time 1', 'processing time', 'samples'],inplace=True)

# %% [markdown]
# ### Univariate Analysis

# %%
df.describe()
# Out:
#         deathrate      dose 1      time 2      dose 2      time 3      dose 3  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean     0.206627    0.619157   10.889963    0.228965   17.524675    0.047333
# std      0.089788    0.083229    1.605921    0.054433    4.413388    0.059794
# min      0.078000    0.414400    5.940000    0.034500   10.330000    0.000000
# 25%      0.138000    0.557500    9.837500    0.197075   14.617500    0.002500
# 50%      0.190000    0.615750   10.820000    0.233150   16.280000    0.016300
# 75%      0.241500    0.676925   11.972500    0.268050   18.870000    0.085650
# max      0.418000    0.852900   15.950000    0.370900   36.920000    0.279900
#
#        processing time     quitAll
# count       800.000000  800.000000
# mean       5406.432038    0.105000
# std         776.061863    0.080518
# min        2473.850000    0.010000
# 25%        5279.445000    0.047500
# 50%        5409.585000    0.085000
# 75%        5553.810000    0.127500
# max        8620.960000    0.300000

# %%
df.deathrate.value_counts(normalize=False)
# Out:
# 0.132    9
# 0.087    8
# 0.118    8
# 0.210    8
# 0.200    8
#         ..
# 0.236    1
# 0.143    1
# 0.152    1
# 0.097    1
# 0.405    1
# Name: deathrate, Length: 232, dtype: int64

# %%
df["dose 1"].value_counts()
# Out:
# 0.6053    4
# 0.5691    3
# 0.6822    3
# 0.7083    3
# 0.5066    2
#          ..
# 0.5672    1
# 0.6572    1
# 0.5921    1
# 0.5746    1
# 0.7781    1
# Name: dose 1, Length: 719, dtype: int64

# %%
print(f"skewness: {df['deathrate'].skew()}")
# Out:
# skewness: 0.8292612919070651

# %%
print(f"kurtosis: {df['deathrate'].kurt()}")
# Out:
# kurtosis: -0.14665085186799942

# %%
plt.figure(figsize=(25,20))
sns.set(style="darkgrid")
ax = sns.boxplot(x='quitAll',y='deathrate', data=df)
ax.axes.set_title("Boxplots of change in death rate with increasing quitAll parameter",fontsize=30)
ax.set_xlabel("quitAll",fontsize=20)
ax.set_ylabel("Death rate",fontsize=20)
ax.tick_params(labelsize=15)
plt.show()

# %%
import seaborn as sns
sns.set()
# Create subplots 
fig, axes = plt.subplots(nrows=4, ncols=4)
fig.subplots_adjust(hspace=1)
fig.suptitle('Distributions of death rate for various quitAll parameters')

# Generate histograms
for ax, (name, subdf) in zip(axes.flatten(), df.groupby('quitAll')):
    sns.histplot(subdf, x='deathrate', ax=ax, kde=True)
    ax.set_title(name)

plt.show()

# %%
sns.pairplot(df,hue='quitAll')

# %%
corrmat = df.corr()
hm = sns.heatmap(corrmat, cbar = True, annot = True, square = True, fmt = '.2f', annot_kws={'size':15}, 
                 yticklabels=df.columns, xticklabels=df.columns, cmap='Spectral_r')
plt.show()

# %%
sns.scatterplot(x='dose 1', y="deathrate", hue="quitAll", data=df, palette="flare", s=80)
plt.title("Relationship between death rate and amount of 1st Dose")
plt.show()

# %%
# Create the figure

plt.rcParams["figure.figsize"] = [20, 15]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Generate the values
x = df["dose 1"]
y = df["time 2"]
z = df["deathrate"]

# Plot the values
ax.scatter(x, y, z, c = 'b', marker='o')
ax.set_xlabel('Amount of 1st Dose')
ax.set_ylabel('time of Dose 2')
ax.set_zlabel('Death rate')
ax.set_title
plt.show()

# %%
New_subset = df.loc[:499,['deathrate', 'dose 1', 'quitAll']]
New_subset
# Out:
#      deathrate  dose 1  quitAll
# 0        0.087  0.5066     0.01
# 1        0.095  0.5798     0.01
# 2        0.087  0.5061     0.01
# 3        0.086  0.4954     0.01
# 4        0.087  0.5241     0.01
# ..         ...     ...      ...
# 495      0.202  0.6400     0.10
# 496      0.196  0.6234     0.10
# 497      0.202  0.6649     0.10
# 498      0.205  0.5707     0.10
# 499      0.199  0.6304     0.10
#
# [500 rows x 3 columns]

# %%
sns.scatterplot(x='dose 1', y="deathrate", data=New_subset, palette="flare", s=80, hue="quitAll")
plt.title("Relationship between deathrate and amount of 1st dosage")
plt.show()
