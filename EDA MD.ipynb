# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %%
plt.style.use("ggplot")
rcParams['figure.figsize'] = (15,10)

# %%
df = pd.read_csv("C:\\Users\\ammar\\OneDrive - University of Stirling\\Documents\\University of Stirling\\MSc Big Data\\Dissertation\\Condor Results\\missDose results\\MDresults.csv")

# %%
df
# Out:
#      deathrate  ABdose  time 1  dose 1  time 2  dose 2  time 3  dose 3  \
# 0        0.084  0.8843       2  0.5059    8.10  0.2275   15.08  0.1510
# 1        0.086  0.8957       2  0.5108    7.88  0.2557   14.90  0.1291
# 2        0.087  0.8878       2  0.4429    8.39  0.1478   14.04  0.2971
# 3        0.077  0.8961       2  0.4762    9.65  0.2193   15.03  0.2005
# 4        0.085  0.8888       2  0.5253    9.94  0.1762   15.12  0.1873
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 795      0.407  0.8924       2  0.7864   13.39  0.0838   17.27  0.0222
# 796      0.407  0.8985       2  0.7921   11.01  0.1022   16.38  0.0042
# 797      0.404  0.9000       2  0.7002   11.42  0.1996   12.55  0.0001
# 798      0.409  0.8958       2  0.6600   10.74  0.2203   13.41  0.0155
# 799      0.414  0.8996       2  0.8286   12.17  0.0709   29.51  0.0001
#
#      processing time  samples  missDose
# 0            5193.08     1000      0.01
# ...

# %%
# Group means
means = df.groupby("missDose").mean().reset_index("missDose")
display(means)
# Out:
#     missDose  deathrate    ABdose  time 1    dose 1   time 2    dose 2  \
# 0       0.01    0.08262  0.895090     2.0  0.492888   8.6688  0.223444
# 1       0.02    0.09552  0.894916     2.0  0.500218   8.9170  0.222584
# 2       0.03    0.10724  0.895132     2.0  0.504526   9.0364  0.211800
# 3       0.04    0.11986  0.894506     2.0  0.513666   9.2306  0.208670
# 4       0.05    0.13260  0.895836     2.0  0.529822   9.1268  0.210522
# 5       0.06    0.14602  0.894722     2.0  0.528616   9.3020  0.208374
# 6       0.07    0.15696  0.894272     2.0  0.529954   9.4564  0.206734
# 7       0.08    0.16842  0.894162     2.0  0.546768   9.0556  0.198302
# 8       0.09    0.18282  0.892336     2.0  0.559998   9.0876  0.189276
# 9       0.10    0.19298  0.893674     2.0  0.561346   9.3694  0.194376
# 10      0.11    0.20512  0.895492     2.0  0.567736   9.4034  0.190564
# 11      0.12    0.21810  0.894734     2.0  0.586202   9.8210  0.183346
# ...

# %%
# Group Stds (equal variances ?)
stds = df.groupby("missDose").std(ddof=1).reset_index()
display(stds)
# Out:
#     missDose  deathrate    ABdose  time 1    dose 1    time 2    dose 2  \
# 0       0.01   0.004823  0.003946     0.0  0.034884  1.251780  0.041000
# 1       0.02   0.003808  0.004272     0.0  0.035805  1.162868  0.040968
# 2       0.03   0.004212  0.004139     0.0  0.032593  1.343293  0.041897
# 3       0.04   0.004036  0.005341     0.0  0.035610  1.339650  0.036954
# 4       0.05   0.005570  0.003729     0.0  0.039499  1.741768  0.042724
# 5       0.06   0.004688  0.004411     0.0  0.045724  1.254445  0.046544
# 6       0.07   0.005993  0.003791     0.0  0.042221  1.452907  0.037379
# 7       0.08   0.005877  0.004713     0.0  0.037448  1.301334  0.044798
# 8       0.09   0.004843  0.005976     0.0  0.035874  1.593582  0.042816
# 9       0.10   0.006120  0.004644     0.0  0.047420  1.510034  0.045645
# 10      0.11   0.006133  0.003736     0.0  0.045261  1.418182  0.045112
# 11      0.12   0.006383  0.004978     0.0  0.050220  1.552828  0.049207
# ...

# %%
# Plot groups
ax = sns.violinplot(x="missDose", y="deathrate", data=df)
ax = sns.swarmplot(x="missDose", y="deathrate", data=df,
color="white")
ax = sns.swarmplot(x="missDose", y="deathrate", color="black", data=means, size=10)
# Out:
# C:\Users\ammar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 34.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ammar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 42.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ammar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 38.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ammar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 24.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import scipy.stats
import statsmodels.api as sm
#import statsmodels.stats.api as sms
import statsmodels.formula.api as smf
from statsmodels.stats.stattools import jarque_bera

# %%
# ANOVA
lm = smf.ols('deathrate ~ missDose', data=df).fit()
lm

# %%
anova_table = sm.stats.anova_lm(lm, typ=2)
display(anova_table)
# Out:
#             sum_sq     df              F  PR(>F)
# missDose  6.646076    1.0  139869.740563     0.0
# Residual  0.037918  798.0            NaN     NaN

# %%
df.drop(columns=['ABdose', 'time 1', 'processing time', 'samples'],inplace=True)

# %% [markdown]
# ### Univariate Analysis

# %%
df.describe()
# Out:
#         deathrate      ABdose  time 1      dose 1      time 2      dose 2  \
# count  800.000000  800.000000   800.0  800.000000  800.000000  800.000000
# mean     0.195896    0.894628     2.0    0.572741    9.508375    0.188646
# std      0.091463    0.004579     0.0    0.085145    1.585304    0.052878
# min      0.069000    0.870100     2.0    0.409900    4.450000    0.024400
# 25%      0.125000    0.892375     2.0    0.510800    8.440000    0.154850
# 50%      0.176000    0.895700     2.0    0.555500    9.420000    0.190900
# 75%      0.231250    0.898300     2.0    0.614825   10.480000    0.223575
# max      0.423000    0.900000     2.0    0.838100   14.250000    0.359200
#
#            time 3      dose 3  processing time  samples    missDose
# count  800.000000  800.000000       800.000000    800.0  800.000000
# mean    14.548550    0.133240      5606.006775   1000.0    0.105000
# std      2.611519    0.066697       588.278752      0.0    0.080518
# ...

# %%
df.deathrate.value_counts(normalize=False)
# Out:
# 0.145    10
# 0.182    10
# 0.199    10
# 0.116     8
# 0.136     8
#          ..
# 0.367     1
# 0.100     1
# 0.226     1
# 0.219     1
# 0.414     1
# Name: deathrate, Length: 243, dtype: int64

# %%
df["dose 1"].value_counts()
# Out:
# 0.5108    4
# 0.5456    3
# 0.5957    3
# 0.5208    3
# 0.5560    3
#          ..
# 0.5118    1
# 0.5536    1
# 0.4480    1
# 0.5310    1
# 0.8286    1
# Name: dose 1, Length: 694, dtype: int64

# %%
print(f"skewness: {df['deathrate'].skew()}")
# Out:
# skewness: 0.9353371004635028

# %%
print(f"kurtosis: {df['deathrate'].kurt()}")
# Out:
# kurtosis: -0.035370377454868596

# %%
plt.figure(figsize=(25,20))
sns.set(style="darkgrid")
ax = sns.boxplot(x='missDose',y='deathrate', data=df)
ax.axes.set_title("Boxplots of change in death rate with increasing missDose parameter",fontsize=30)
ax.set_xlabel("missDose",fontsize=20)
ax.set_ylabel("Death rate",fontsize=20)
ax.tick_params(labelsize=15)
plt.show()

# %%
import seaborn as sns
sns.set()
# Create subplots 
fig, axes = plt.subplots(nrows=4, ncols=4)
fig.subplots_adjust(hspace=1)
fig.suptitle('Distributions of death rate for various missDose parameters')

# Generate histograms
for ax, (name, subdf) in zip(axes.flatten(), df.groupby('missDose')):
    sns.histplot(subdf, x='deathrate', ax=ax, kde=True)
    ax.set_title(name)

plt.show()

# %%
sns.pairplot(df,hue='missDose')

# %%
corrmat = df.corr()
hm = sns.heatmap(corrmat, cbar = True, annot = True, square = True, fmt = '.2f', annot_kws={'size':15}, 
                 yticklabels=df.columns, xticklabels=df.columns, cmap='Spectral_r')
plt.show()

# %%
sns.scatterplot(x='dose 1', y="deathrate", hue="missDose", data=df, palette="flare", s=80)
plt.title("Relationship between death rate and amount of 1st Dose")
plt.show()

# %%
sns.scatterplot(x='dose 2', y="deathrate", hue="missDose", data=df, palette="flare", s=80)
plt.title("Relationship between deathrate, dose 2 amount and quitAll parameter")
plt.show()

# %%
# Create the figure

plt.rcParams["figure.figsize"] = [20, 15]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Generate the values
x = df["dose 1"]
y = df["time 2"]
z = df["deathrate"]

# Plot the values
ax.scatter(x, y, z, c = 'b', marker='o')
ax.set_xlabel('Amount of 1st Dose')
ax.set_ylabel('time of Dose 2')
ax.set_zlabel('Death rate')
ax.set_title
plt.show()

# %%
New_subset = df.loc[:499,['deathrate', 'dose 1', 'missDose']]
New_subset
# Out:
#      deathrate  dose 1  missDose
# 0        0.084  0.5059      0.01
# 1        0.086  0.5108      0.01
# 2        0.087  0.4429      0.01
# 3        0.077  0.4762      0.01
# 4        0.085  0.5253      0.01
# ..         ...     ...       ...
# 495      0.186  0.5777      0.10
# 496      0.192  0.4807      0.10
# 497      0.198  0.5649      0.10
# 498      0.199  0.6588      0.10
# 499      0.187  0.5371      0.10
#
# [500 rows x 3 columns]

# %%
sns.scatterplot(x='dose 1', y="deathrate", data=New_subset, palette="flare", s=80, hue="missDose")
plt.title("Relationship between deathrate and amount of 1st dosage")
plt.show()

# %%
sns.lineplot(x='missDose', y="deathrate", data=df)
plt.title("Relationship between deathrate and missDose parameter")
plt.show()

# %%
sns.barplot(x='missDose', y="dose 1", data=df)
plt.title("Relationship between missDose and amount of 1st dosage")
plt.show()

# %%
sns.barplot(x='missDose', y="dose 2", data=df)
plt.title("Relationship between missDose and amount of 2nd dosage")
plt.show()

# %%
sns.barplot(x='missDose', y="dose 3", data=df)
plt.title("Relationship between missDose and amount of 3rd dosage")
plt.show()
