# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from scipy import stats

# %%
plt.style.use("ggplot")
rcParams['figure.figsize'] = (15,10)

# %%
df = pd.read_csv("C:\\Users\\ammar\\OneDrive - University of Stirling\\Documents\\University of Stirling\\MSc Big Data\\Dissertation\\Condor Results\\HourVariance results\\HVVresults.csv")

# %%
df
# Out:
#      deathrate  maxABdose  time 1  dose 1  time 2  dose 2  time 3  dose 3  \
# 0        0.059     0.8997       2  0.4857    8.00  0.2210   15.07  0.1931
# 1        0.061     0.8991       2  0.4657    7.89  0.1790   15.14  0.2545
# 2        0.072     0.8954       2  0.5044    9.30  0.2715   15.98  0.1195
# 3        0.074     0.8899       2  0.4792    7.53  0.2018   12.74  0.2090
# 4        0.066     0.8990       2  0.4569    8.86  0.2472   16.05  0.1949
# ..         ...        ...     ...     ...     ...     ...     ...     ...
# 995      0.070     0.8990       2  0.5493    8.97  0.1635   14.88  0.1862
# 996      0.073     0.8979       2  0.5259    7.25  0.1905   15.12  0.1815
# 997      0.069     0.8977       2  0.4834    7.91  0.2283   14.82  0.1859
# 998      0.077     0.8963       2  0.4773    6.33  0.2193   13.84  0.1996
# 999      0.071     0.8939       2  0.4429    7.02  0.2328   12.63  0.2182
#
#      processing time  samples  HourVariance
# ...

# %%
# Group means
means = df.groupby("HourVariance").mean().reset_index("HourVariance")
display(means)
# Out:
#     HourVariance  deathrate  maxABdose  time 1    dose 1  time 2    dose 2  \
# 0           0.02    0.07034   0.895940     2.0  0.491612  8.7292  0.235694
# 1           0.04    0.06968   0.896602     2.0  0.483044  8.6602  0.229488
# 2           0.06    0.07008   0.895540     2.0  0.481166  8.6312  0.232770
# 3           0.08    0.07008   0.896028     2.0  0.482598  8.5998  0.235960
# 4           0.10    0.07034   0.894954     2.0  0.475882  8.2448  0.228504
# 5           0.12    0.07094   0.895884     2.0  0.478590  8.6188  0.251512
# 6           0.14    0.07044   0.895884     2.0  0.487318  8.7570  0.232744
# 7           0.16    0.06972   0.895850     2.0  0.482730  8.5384  0.223320
# 8           0.18    0.07008   0.896138     2.0  0.483920  8.6042  0.230584
# 9           0.20    0.06952   0.895248     2.0  0.484046  8.7424  0.224384
# 10          0.25    0.07028   0.894892     2.0  0.476864  8.7222  0.227734
# ...

# %%
# Group Stds (equal variances ?)
stds = df.groupby("HourVariance").std(ddof=1).reset_index()
display(stds)
# Out:
#     HourVariance  deathrate  maxABdose  time 1    dose 1    time 2    dose 2  \
# 0           0.02   0.004658   0.004048     0.0  0.035404  1.244532  0.040907
# 1           0.04   0.004560   0.003041     0.0  0.035272  1.328124  0.041171
# 2           0.06   0.004125   0.003762     0.0  0.037521  1.338088  0.041819
# 3           0.08   0.004198   0.003266     0.0  0.036970  1.371443  0.034846
# 4           0.10   0.004350   0.003827     0.0  0.035942  1.519291  0.043738
# 5           0.12   0.004657   0.003309     0.0  0.037150  1.433574  0.038464
# 6           0.14   0.005603   0.003606     0.0  0.036804  1.491107  0.044814
# 7           0.16   0.005014   0.003721     0.0  0.039463  1.428996  0.034309
# 8           0.18   0.004890   0.003318     0.0  0.038667  1.165392  0.035527
# 9           0.20   0.004112   0.003745     0.0  0.034718  1.492165  0.033291
# 10          0.25   0.002857   0.004383     0.0  0.033848  1.205987  0.039828
# ...

# %%
# Plot groups
ax = sns.violinplot(x="HourVariance", y="deathrate", data=df)
ax = sns.swarmplot(x="HourVariance", y="deathrate", data=df,
color="white")
ax = sns.swarmplot(x="HourVariance", y="deathrate", color="black", data=means, size=10)
# Out:
# C:\Users\ammar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ammar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ammar\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import scipy.stats
import statsmodels.api as sm
#import statsmodels.stats.api as sms
import statsmodels.formula.api as smf
from statsmodels.stats.stattools import jarque_bera

# %%
# ANOVA
lm = smf.ols('deathrate ~ HourVariance', data=df).fit()
lm

# %%
anova_table = sm.stats.anova_lm(lm, typ=2)
display(anova_table)
# Out:
#                 sum_sq     df         F    PR(>F)
# HourVariance  0.000003    1.0  0.147054  0.701449
# Residual      0.017878  998.0       NaN       NaN

# %%
df.drop(columns=['maxABdose', 'time 1', 'processing time', 'samples'],inplace=True)

# %% [markdown]
# ### Univariate Analysis

# %%
df.describe()
# Out:
#          deathrate       dose 1       time 2       dose 2       time 3  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.070067     0.482775     8.465830     0.232426    14.409340
# std       0.004231     0.035686     1.369167     0.039591     1.694508
# min       0.053000     0.381100     3.090000     0.123900     8.000000
# 25%       0.067000     0.458350     7.560000     0.205200    13.320000
# 50%       0.070000     0.482250     8.530000     0.231900    14.430000
# 75%       0.072000     0.506975     9.370000     0.258275    15.502500
# max       0.093000     0.611000    13.640000     0.392400    32.500000
#
#             dose 3  HourVariance
# count  1000.000000   1000.000000
# mean      0.180372      0.317500
# std       0.044076      0.257556
# min       0.000700      0.020000
# 25%       0.153675      0.115000
# 50%       0.182350      0.225000
# 75%       0.211400      0.462500
# max       0.289200      0.900000

# %%
df.deathrate.value_counts(normalize=False)
# Out:
# 0.070    114
# 0.071    113
# 0.069    105
# 0.068     93
# 0.072     86
# 0.067     75
# 0.066     73
# 0.073     73
# 0.075     44
# 0.074     43
# 0.065     34
# 0.064     25
# 0.076     23
# 0.063     22
# 0.077     18
# 0.062     12
# 0.078      7
# 0.079      7
# 0.061      6
# 0.086      4
# 0.081      4
# 0.082      3
# 0.059      3
# 0.060      2
# 0.084      2
# 0.089      1
# 0.092      1
# 0.091      1
# 0.053      1
# 0.087      1
# 0.093      1
# 0.058      1
# 0.088      1
# 0.080      1
# Name: deathrate, dtype: int64

# %%
df["dose 1"].value_counts()
# Out:
# 0.4763    6
# 0.4738    6
# 0.4737    5
# 0.4751    5
# 0.4888    5
#          ..
# 0.4731    1
# 0.4684    1
# 0.4501    1
# 0.5183    1
# 0.4429    1
# Name: dose 1, Length: 708, dtype: int64

# %%
print(f"skewness: {df['deathrate'].skew()}")
# Out:
# skewness: 0.8268731549182182

# %%
print(f"kurtosis: {df['deathrate'].kurt()}")
# Out:
# kurtosis: 3.4759983654279067

# %%
plt.figure(figsize=(25,20))
sns.set(style="darkgrid")
ax = sns.boxplot(x='HourVariance',y='deathrate', data=df)
ax.axes.set_title("Boxplots of change in death rate with increasing HourVariance parameter",fontsize=30)
ax.set_xlabel("Hour Variance",fontsize=20)
ax.set_ylabel("Death rate",fontsize=20)
ax.tick_params(labelsize=15)
plt.show()

# %%
import seaborn as sns
sns.set()
# Create subplots 
fig, axes = plt.subplots(nrows=4, ncols=4)
fig.subplots_adjust(hspace=1)
fig.suptitle('Distributions of death rate for various HourVariance parameters')

# Generate histograms
for ax, (name, subdf) in zip(axes.flatten(), df.groupby('HourVariance')):
    sns.histplot(subdf, x='deathrate', ax=ax, kde=True)
    ax.set_title(name)

plt.show()

# %%
sns.pairplot(df,hue='HourVariance')

# %%
corrmat = df.corr()
hm = sns.heatmap(corrmat, cbar = True, annot = True, square = True, fmt = '.2f', annot_kws={'size':15}, 
                 yticklabels=df.columns, xticklabels=df.columns, cmap='Spectral_r')
plt.show()

# %%
sns.scatterplot(x='dose 1', y="deathrate", hue="HourVariance", data=df, palette="flare", s=80)
plt.title("Relationship between death rate and amount of 1st Dose")
plt.show()

# %%
# Create the figure

plt.rcParams["figure.figsize"] = [20, 15]
plt.rcParams["figure.autolayout"] = True

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Generate the values
x = df["dose 1"]
y = df["time 2"]
z = df["deathrate"]

# Plot the values
ax.scatter(x, y, z, c = 'b', marker='o')
ax.set_xlabel('Amount of 1st Dose')
ax.set_ylabel('time of Dose 2')
ax.set_zlabel('Death rate')
ax.set_title
plt.show()

# %%
New_subset = df.loc[:499,['deathrate', 'dose 1', 'HourVariance']]
New_subset
# Out:
#      deathrate  dose 1  HourVariance
# 0        0.059  0.4857          0.02
# 1        0.061  0.4657          0.02
# 2        0.072  0.5044          0.02
# 3        0.074  0.4792          0.02
# 4        0.066  0.4569          0.02
# ..         ...     ...           ...
# 495      0.067  0.4104          0.20
# 496      0.077  0.5214          0.20
# 497      0.069  0.5156          0.20
# 498      0.072  0.5156          0.20
# 499      0.068  0.4743          0.20
#
# [500 rows x 3 columns]

# %%
sns.lineplot(x='HourVariance', y="deathrate", data=df)
plt.title("Relationship between deathrate and HourVariance parameter")
plt.show()

# %%
sns.barplot(x='HourVariance', y="dose 1", data=df)
plt.title("Relationship between HourVariance and amount of 1st dosage")
plt.show()

# %%
sns.barplot(x='HourVariance', y="dose 2", data=df)
plt.title("Relationship between HourVariance and amount of 2nd dosage")
plt.show()

# %%
sns.barplot(x='HourVariance', y="dose 3", data=df)
plt.title("Relationship between HourVariance and amount of 3rd dosage")
plt.show()
